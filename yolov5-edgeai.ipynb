# %%
# !nvidia-smi

# %%
# !git clone https://github.com/daiv123/edgeai-yolov5

# %%
from google.colab import drive
drive.mount('/content/drive')
#folder at https://drive.google.com/drive/folders/1qXTj54g_sBFZSCRVAfcEZatcpB-rzuTx?usp=sharing

# %%
# !cp /content/drive/MyDrive/facemask/facemask.yaml /content/edgeai-yolov5/data/facemask.yaml

# %%
# %cd /content/edgeai-yolov5/
# !pip install -r requirements.txt
# !pip install wandb

# %%
# !python3 train.py --data facemask.yaml --weights yolov5s6.pt --batch-size 16 --epochs 50

# %%
# !ls /content/drive/MyDrive/facemask/facemask

# %%
from google.colab import files
# !zip -r /content/run.zip /content/edgeai-yolov5/runs/train/exp/

# %%
# !python export.py --weights runs/train/exp/weights/best.pt  --img 640 --batch 1 --simplify --export-nms --opset 11 # export at 640x640 with batch size 1

# %%
# !rm -rf /content/edgeai-yolov5/runs/val/

# %%
# !rm -rf /content/models/*

# %%
# !python val.py --img 640 --data facemask.yaml --weights ../models/best.pt
# Out:
# val: data=./data/facemask.yaml, weights=['../models/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 v5.0-327-gf719208 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Model Summary: 297 layers, 12353476 parameters, 0 gradients, 16.8 GFLOPs
# ...

# %%
# !zip -r /content/val.zip /content/edgeai-yolov5/runs/val/
# Out:
#   adding: content/edgeai-yolov5/runs/val/ (stored 0%)
#   adding: content/edgeai-yolov5/runs/val/exp3/ (stored 0%)
#   adding: content/edgeai-yolov5/runs/val/exp3/F1_curve.png (deflated 12%)
#   adding: content/edgeai-yolov5/runs/val/exp3/val_batch0_labels.jpg (deflated 5%)
#   adding: content/edgeai-yolov5/runs/val/exp3/confusion_matrix.png (deflated 31%)
#   adding: content/edgeai-yolov5/runs/val/exp3/PR_curve.png (deflated 12%)
#   adding: content/edgeai-yolov5/runs/val/exp3/P_curve.png (deflated 11%)
#   adding: content/edgeai-yolov5/runs/val/exp3/val_batch0_pred.jpg (deflated 5%)
#   adding: content/edgeai-yolov5/runs/val/exp3/val_batch1_labels.jpg (deflated 7%)
#   adding: content/edgeai-yolov5/runs/val/exp3/val_batch2_labels.jpg (deflated 8%)
#   adding: content/edgeai-yolov5/runs/val/exp3/R_curve.png (deflated 13%)
#   adding: content/edgeai-yolov5/runs/val/exp3/val_batch1_pred.jpg (deflated 7%)
# ...

# %%
# !cp /content/val.zip /content/drive/MyDrive/val.zip
